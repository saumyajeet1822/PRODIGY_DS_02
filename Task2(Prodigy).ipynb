# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyajeet1822/PRODIGY_DS_02/blob/main/Task2(Prodigy).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Country-data.csv')

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# 2     16.100        76.5       2.89   4460
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no Duplicated Values in the Dataset.**

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# **There are No Null Values in the Dataset at all.**

# %%
df.shape
# Out:
# (167, 10)

# %%
df_cpy = df

# %%
df= df.drop(columns='country')

# %%
df.head()
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2        27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3       119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4        10.3     45.5    6.03     58.9   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_cpy.sort_values('child_mort',ascending=False).head(10)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 97                       Mali       137.0     22.8    4.98     35.1    1870
# 113                   Nigeria       130.0     25.3    5.07     17.4    5150
# 112                     Niger       123.0     22.2    5.16     49.1     814
# 3                      Angola       119.0     62.3    2.85     42.9    5900
# 25               Burkina Faso       116.0     19.2    6.74     29.6    1430
# 37           Congo, Dem. Rep.       116.0     41.1    7.91     49.6     609
#
#      inflation  life_expec  total_fer  gdpp
# 66        5.45        32.1       3.33   662
# ...

# %% [markdown]
# **These Are the Top 10 Countries Having Very High Child Mortality Rate.Which Is Not Good for a Good Country.**

# %%
df_cpy.sort_values('gdpp',ascending=True).head(10)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 26                    Burundi        93.6     8.92   11.60     39.2     764
# 88                    Liberia        89.3    19.10   11.80     92.6     700
# 37           Congo, Dem. Rep.       116.0    41.10    7.91     49.6     609
# 112                     Niger       123.0    22.20    5.16     49.1     814
# 132              Sierra Leone       160.0    16.80   13.10     34.5    1220
# 93                 Madagascar        62.2    25.00    3.77     43.0    1390
# 106                Mozambique       101.0    31.50    5.21     46.2     918
# 31   Central African Republic       149.0    11.80    3.98     26.5     888
# 94                     Malawi        90.5    22.80    6.59     34.9    1030
# 50                    Eritrea        55.2     4.79    2.66     23.3    1420
#
#      inflation  life_expec  total_fer  gdpp
# 26       12.30        57.7       6.26   231
# ...

# %% [markdown]
# **These are 10 Countries Having lowest GDPP.**

# %%
df_cpy.sort_values('inflation',ascending=False).head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 113            Nigeria       130.0     25.3    5.07     17.4    5150
# 163          Venezuela        17.1     28.5    4.91     17.6   16500
# 103           Mongolia        26.1     46.7    5.44     56.7    7710
# 149        Timor-Leste        62.6      2.2    9.12     27.8    1850
# 49   Equatorial Guinea       111.0     85.8    4.48     58.9   33700
# 165              Yemen        56.3     30.0    5.18     34.4    4480
# 140          Sri Lanka        11.2     19.6    2.94     26.8    8560
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 37    Congo, Dem. Rep.       116.0     41.1    7.91     49.6     609
#
#      inflation  life_expec  total_fer   gdpp
# 113      104.0        60.5       5.84   2330
# 163       45.9        75.4       2.47  13500
# 103       39.2        66.2       2.64   2650
# ...

# %% [markdown]
# **The List of 10 Countries Having High Inflation Rate.**

# %%
df_cpy.sort_values('health',ascending=True).head(10)
# Out:
#           country  child_mort  exports  health  imports  income  inflation  \
# 123         Qatar         9.0   62.300    1.81  23.8000  125000       6.98
# 107       Myanmar        64.4    0.109    1.97   0.0659    3720       7.04
# 116      Pakistan        92.1   13.500    2.20  19.4000    4280      10.90
# 38    Congo, Rep.        63.9   85.100    2.46  54.7000    5190      20.70
# 154  Turkmenistan        62.0   76.300    2.50  44.5000    9940       2.31
# 70      Indonesia        33.3   24.300    2.61  22.4000    8430      15.30
# 82         Kuwait        10.8   66.700    2.63  30.4000   75200      11.20
# 50        Eritrea        55.2    4.790    2.66  23.3000    1420      11.60
# 115          Oman        11.7   65.700    2.77  41.2000   45300      15.60
# 23         Brunei        10.5   67.400    2.84  28.0000   80600      16.70
#
#      life_expec  total_fer   gdpp
# 123        79.5       2.07  70300
# 107        66.8       2.41    988
# 116        65.3       3.85   1040
# ...

# %% [markdown]
# **10 Countries Which Are Very Low in Health.But here we can see that health is given as percentage of gdpp so this sorting did not judge accurate health wise report so finding health expenditure in next cell.**

# %%
df_cpy.health = ((df_cpy.health*df_cpy.gdpp)/100)

# %%
df_cpy.sort_values('health',ascending=True).head(10)
# Out:
#                       country  child_mort  exports   health  imports  income  \
# 50                    Eritrea        55.2    4.790  12.8212  23.3000    1420
# 93                 Madagascar        62.2   25.000  15.5701  43.0000    1390
# 31   Central African Republic       149.0   11.800  17.7508  26.5000     888
# 112                     Niger       123.0   22.200  17.9568  49.1000     814
# 107                   Myanmar        64.4    0.109  19.4636   0.0659    3720
# 106                Mozambique       101.0   31.500  21.8299  46.2000     918
# 116                  Pakistan        92.1   13.500  22.8800  19.4000    4280
# 37           Congo, Dem. Rep.       116.0   41.100  26.4194  49.6000     609
# 12                 Bangladesh        49.4   16.000  26.6816  21.8000    2440
# 26                    Burundi        93.6    8.920  26.7960  39.2000     764
#
#      inflation  life_expec  total_fer  gdpp
# 50       11.60        61.7       4.61   482
# ...

# %%
df_cpy.exports = ((df_cpy.exports*df_cpy.gdpp)/100)
df_cpy.imports = ((df_cpy.imports*df_cpy.gdpp)/100)

# %%
df_cpy.sort_values('imports',ascending=False).head(10)
# Out:
#          country  child_mort   exports   health   imports  income  inflation  \
# 91    Luxembourg         2.8  183750.0  8158.50  149100.0   91700      3.620
# 133    Singapore         2.8   93200.0  1845.36   81084.0   72100     -0.046
# 73       Ireland         4.2   50161.0  4475.53   42125.5   45700     -3.220
# 145  Switzerland         4.5   47744.0  8579.00   39761.8   55500      0.317
# 15       Belgium         4.5   33921.6  4750.80   33166.8   41100      1.880
# 98         Malta         6.8   32283.0  1825.15   32494.0   28300      3.830
# 110  Netherlands         4.5   36216.0  5985.70   31990.8   45500      0.848
# 44       Denmark         4.1   29290.0  6612.00   25288.0   44000      3.220
# 114       Norway         3.2   34856.6  8323.44   25023.0   62300      5.950
# 8        Austria         4.3   24059.7  5159.00   22418.2   43200      0.873
#
#      life_expec  total_fer    gdpp
# 91         81.3       1.63  105000
# 133        82.7       1.15   46600
# ...

# %% [markdown]
# **10 Countries Having Highest Imports ie More import leads to bad Country Economy.**

# %%
df_cpy.sort_values('exports',ascending=True).head(10)
# Out:
#                       country  child_mort   exports   health     imports  \
# 107                   Myanmar        64.4   1.07692  19.4636    0.651092
# 26                    Burundi        93.6  20.60520  26.7960   90.552000
# 50                    Eritrea        55.2  23.08780  12.8212  112.306000
# 31   Central African Republic       149.0  52.62800  17.7508  118.190000
# 0                 Afghanistan        90.2  55.30000  41.9174  248.297000
# 109                     Nepal        47.0  56.71360  31.0800  215.488000
# 88                    Liberia        89.3  62.45700  38.5860  302.802000
# 132              Sierra Leone       160.0  67.03200  52.2690  137.655000
# 126                    Rwanda        63.6  67.56000  59.1150  168.900000
# 112                     Niger       123.0  77.25600  17.9568  170.868000
#
#      income  inflation  life_expec  total_fer  gdpp
# 107    3720       7.04        66.8       2.41   988
# 26      764      12.30        57.7       6.26   231
# ...

# %% [markdown]
# **10 Countries Having lowest exports.**

# %%
df_cpy.sort_values('life_expec',ascending=True).head(10)
# Out:
#                       country  child_mort   exports    health   imports  \
# 66                      Haiti       208.0   101.286   45.7442   428.314
# 87                    Lesotho        99.7   460.980  129.8700  1181.700
# 31   Central African Republic       149.0    52.628   17.7508   118.190
# 166                    Zambia        83.1   540.200   85.9940   451.140
# 94                     Malawi        90.5   104.652   30.2481   160.191
# 137              South Africa        53.7  2082.080  650.8320  1994.720
# 106                Mozambique       101.0   131.985   21.8299   193.578
# 132              Sierra Leone       160.0    67.032   52.2690   137.655
# 64              Guinea-Bissau       114.0    81.503   46.4950   192.544
# 0                 Afghanistan        90.2    55.300   41.9174   248.297
#
#      income  inflation  life_expec  total_fer  gdpp
# 66     1500       5.45        32.1       3.33   662
# 87     2380       4.15        46.5       3.30  1170
# ...

# %% [markdown]
# Countries In which Life Expectancy is Lowest

# %%
df_cpy.sort_values('total_fer',ascending=False).head(10)
# Out:
#               country  child_mort    exports    health   imports  income  \
# 112             Niger       123.0    77.2560   17.9568   170.868     814
# 32               Chad       150.0   330.0960   40.6341   390.195    1930
# 97               Mali       137.0   161.4240   35.2584   248.508    1870
# 37   Congo, Dem. Rep.       116.0   137.2740   26.4194   165.664     609
# 26            Burundi        93.6    20.6052   26.7960    90.552     764
# 149       Timor-Leste        62.6    79.2000  328.3200  1000.800    1850
# 3              Angola       119.0  2199.1900  100.6050  1514.370    5900
# 155            Uganda        81.0   101.7450   53.6095   170.170    1540
# 25       Burkina Faso       116.0   110.4000   38.7550   170.200    1430
# 113           Nigeria       130.0   589.4900  118.1310   405.420    5150
#
#      inflation  life_expec  total_fer  gdpp
# 112       2.55        58.8       7.49   348
# 32        6.39        56.5       6.59   897
# ...

# %% [markdown]
# **Total Fertility Rate Highest 10 countries.**

# %%
df = df_cpy.drop(columns='country')

# %%
sns.pairplot(data=df)

# %%
df.corr()
# Out:
#             child_mort   exports    health   imports    income  inflation  \
# child_mort    1.000000 -0.297230 -0.430438 -0.319138 -0.524315   0.288276
# exports      -0.297230  1.000000  0.612919  0.987686  0.725351  -0.141553
# health       -0.430438  0.612919  1.000000  0.638581  0.690857  -0.253956
# imports      -0.319138  0.987686  0.638581  1.000000  0.672056  -0.179458
# income       -0.524315  0.725351  0.690857  0.672056  1.000000  -0.147756
# inflation     0.288276 -0.141553 -0.253956 -0.179458 -0.147756   1.000000
# life_expec   -0.886676  0.377694  0.545626  0.397515  0.611962  -0.239705
# total_fer     0.848478 -0.291096 -0.407984 -0.317061 -0.501840   0.316921
# gdpp         -0.483032  0.768894  0.916593  0.755114  0.895571  -0.221631
#
#             life_expec  total_fer      gdpp
# child_mort   -0.886676   0.848478 -0.483032
# exports       0.377694  -0.291096  0.768894
# health        0.545626  -0.407984  0.916593
# imports       0.397515  -0.317061  0.755114
# ...

# %%
sns.heatmap(data=df.corr(),cmap='RdBu_r', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **There is Highest Correlation is betweeen<br> health and gdpp which is 0.95<br> income and gdpp which is 0.9 <br> child mortality and total Fertality Which is 0.85<br>
# 0.77 Which is between exports and gdpp.**

# %% [markdown]
# **As Gdpp is correlated With Many of features like Health income exports imports so the Major factor we can take into consideration for deciding Countries is<br>1. GDPP then<br>2. Child Mortality<br>**

# %%
df.describe()
# Out:
#        child_mort        exports       health        imports         income  \
# count  167.000000     167.000000   167.000000     167.000000     167.000000
# mean    38.270060    7420.618847  1056.733204    6588.352108   17144.688623
# std     40.328931   17973.885795  1801.408906   14710.810418   19278.067698
# min      2.600000       1.076920    12.821200       0.651092     609.000000
# 25%      8.250000     447.140000    78.535500     640.215000    3355.000000
# 50%     19.300000    1777.440000   321.886000    2045.580000    9960.000000
# 75%     62.100000    7278.000000   976.940000    7719.600000   22800.000000
# max    208.000000  183750.000000  8663.600000  149100.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# ...

# %%
sns.set(rc={'figure.figsize':(10,5)}, font_scale=.75)
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %% [markdown]
# <h4>There are Outliers Present in Exports Gdpp and Income to large Extent. and in Health and Imports are there but very Less. <h4>
